# %%
# !pip install roboflow
#Loading dataset
from roboflow import Roboflow
rf = Roboflow(api_key="R6jVb8NwZ7XOIIlxVzIT")
project = rf.workspace("ntust-lu0wl").project("traditional-paraguayan-snack-detection")
dataset = project.version(2).download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics<=8.0.20 is required but found version=8.0.114, to fix: `pip install ultralytics<=8.0.20`
# ...
# Extracting Dataset Version Zip to Traditional-paraguayan-snack-detection-2 in yolov8:: 100%|█| 612/612 [00:00<00:00, 10

# %%
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

# %%
#Training
# !yolo task=detect mode=train model=yolov8s.pt data={dataset.location}/data.yaml epochs=100 imgsz=640 plots=True
# Out:
# Ultralytics YOLOv8.0.114  Python-3.9.7 torch-2.0.1+cpu CPU
# ...

# %%
#Validate with a new model
# !yolo task=detect mode=val model=C:/Users/david/Desktop/capstone/runs/detect/train2/weights/best.pt data={dataset.location}/data.yaml
# Out:
# Ultralytics YOLOv8.0.114  Python-3.9.7 torch-2.0.1+cpu CPU
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients
#
# val: Scanning C:\Users\david\Desktop\capstone\Traditional-paraguayan-snack-detection-2\valid\labels.cache... 59 images, 0 backgrounds, 0 corrupt: 100%|##########| 59/59 [00:00<?, ?it/s]
# val: Scanning C:\Users\david\Desktop\capstone\Traditional-paraguayan-snack-detection-2\valid\labels.cache... 59 images, 0 backgrounds, 0 corrupt: 100%|##########| 59/59 [00:00<?, ?it/s]
#
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):   0%|          | 0/4 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  25%|##5       | 1/4 [00:07<00:21,  7.01s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  50%|#####     | 2/4 [00:14<00:15,  7.51s/it]
# ...

# %%
#Predict with a custom model
# !yolo task=detect mode=predict model=C:/Users/david/Desktop/capstone/runs/detect/train2/weights/best.pt conf=0.25 source=C:/Users/david/Desktop/capstone/Testing/Sopa/20220728184040164.jpg
# Out:
# Ultralytics YOLOv8.0.114  Python-3.9.7 torch-2.0.1+cpu CPU
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients
#
# image 1/1 C:\Users\david\Desktop\capstone\Testing\Sopa\20220728184040164.jpg: 480x640 1 Food, 282.2ms
# Speed: 3.0ms preprocess, 282.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs\detect\predict6
